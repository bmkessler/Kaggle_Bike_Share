# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('train.csv',parse_dates=['datetime'])

# %%
df.describe()
# Out:
#              season       holiday    workingday       weather         temp  \
# count  10886.000000  10886.000000  10886.000000  10886.000000  10886.00000
# mean       2.506614      0.028569      0.680875      1.418427     20.23086
# std        1.116174      0.166599      0.466159      0.633839      7.79159
# min        1.000000      0.000000      0.000000      1.000000      0.82000
# 25%        2.000000      0.000000      0.000000      1.000000     13.94000
# 50%        3.000000      0.000000      1.000000      1.000000     20.50000
# 75%        4.000000      0.000000      1.000000      2.000000     26.24000
# max        4.000000      1.000000      1.000000      4.000000     41.00000
#
#               atemp      humidity     windspeed        casual    registered  \
# count  10886.000000  10886.000000  10886.000000  10886.000000  10886.000000
# mean      23.655084     61.886460     12.799395     36.021955    155.552177
# ...

# %%
df.columns
# Out:
# Index([u'datetime', u'season', u'holiday', u'workingday', u'weather', u'temp', u'atemp', u'humidity', u'windspeed', u'casual', u'registered', u'count'], dtype='object')

# %%
df.head()
# Out:
#              datetime  season  holiday  workingday  weather  temp   atemp  \
# 0 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3 2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4 2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81          0       3          13     16
# 1        80          0       8          32     40
# 2        80          0       5          27     32
# 3        75          0       3          10     13
# 4        75          0       0           1      1
#
# [5 rows x 12 columns]

# %%
# add hour, day of week, date and month columns to the data frame
df['hour']=df.datetime.map(lambda x: x.hour)
df['weekday']=df.datetime.map(lambda x: x.weekday())
df['date'] = df.datetime.map(lambda x: x.date())
df['month'] = df.datetime.map(lambda x: x.month)

# %%
plt.plot(df['hour'],df['count'],'ro')
plt.show()

# %%
for d in range(7):
    plt.plot(df[df['weekday']==d]['hour'],df[df['weekday']==d]['count'],'ro')
    plt.show()

# %%
avg_users = df.groupby(['weekday','hour']).mean()
for d in avg_users.index.levels[0]:
    avg_users[['casual','registered','count']].xs(d,level='weekday',drop_level=False).plot()
    show()

# %%
plt.plot(df['date'],df['count'])
plt.show()

# %%
daily_avg = df.groupby('date').mean()
daily_avg[['casual','registered','count']].plot()
show()

# %%
for wd in [0,1]:
    df[df.weekday==0].groupby(['holiday','workingday','hour']).mean()['count'].xs(wd,level='workingday',drop_level=False).plot()
    show()

# %% [markdown]
# One of the dumbest models, just predict the results from 14 days ago, could improve by predicting 7 days in the past or 7 days in the future basd on which is closer

# %%
df_test = pd.read_csv('test.csv',parse_dates=['datetime'])

# %%
df_test['offsetdate'] = df_test.datetime.map(lambda x: x + relativedelta(days=-14))

# %%
# merge equals outer join on offsetdate and datetime
simp_bwd = pd.merge(df_test,df,how='left',left_on='offsetdate',right_on='datetime')
out = simp_bwd[['datetime_x','count']].fillna(0)
out.to_csv('simp_bwd.csv')
out.describe()
# Out:
#              count
# count  6493.000000
# mean    193.653473
# std     183.548264
# min       0.000000
# 25%      42.000000
# 50%     146.000000
# 75%     286.000000
# max     977.000000
#
# [8 rows x 1 columns]
